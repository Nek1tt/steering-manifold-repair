# %% [markdown]
# # Steering Manifold Repair — Baseline
#
# Runs the GPT-2 Small + OpenAI SAE additive-steering Pareto baseline. Progress is visible through `tqdm`.

# %%
REPO_URL = 'https://github.com/Nek1tt/steering-manifold-repair.git'
# !git clone $REPO_URL
# %cd steering-manifold-repair
# !pip -q install -r requirements.txt
# !pip -q install -e .

# %%
# Optional quick-run edits before the full sweep
from pathlib import Path
print(Path('configs/baseline_gpt2.yaml').read_text())

# %%
# !python scripts/run_baseline.py --config configs/baseline_gpt2.yaml

# %%
# !python scripts/plot_baseline.py --input results/baseline_samples.csv --output results/baseline_pareto.png
from IPython.display import Image, display
display(Image('results/baseline_pareto.png'))
